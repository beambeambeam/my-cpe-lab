# %% [markdown]
# # Lab 2: Types of Data
#
# #### CPE232 Data Models
#
# ---

# %% [markdown]
# ## [1] CSV

# %%
import csv

# %% [markdown]
# ### 1.1 Writing new csv file
#
# _Note: Remember this example? We've already seen it in the last lab._

# %%
with open("test.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Surname"])
    writer.writerow(["Alice", "Johnson"])
    writer.writerow(["Bob", "Smith"])

# %% [markdown]
# ### 1.2 Reading a csv file

# %%
with open("test.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Surname']
# ['Alice', 'Johnson']
# ['Bob', 'Smith']

# %% [markdown]
# ### 1.3 Use pandas to read csv file

# %%
import pandas as pd

df = pd.read_csv("test.csv")

df
# Out:
#     Name  Surname
# 0  Alice  Johnson
# 1    Bob    Smith

# %% [markdown]
# [Q1] Write a Python script that reads the **students.csv** file and prints the content of _the first 10 students_ row by row.

# %%
import csv

with open("students.csv", newline="") as file:
    reader = csv.reader(file)
    next(reader)  # skip header
    for i, row in enumerate(reader):
        if i == 10:
            break
        print(row)
# Out:
# ['Alice', '21', 'A']
# ['Bob', '22', 'B']
# ['Charlie', '20', 'C']
# ['David', '23', 'A']
# ['Eve', '19', 'B']
# ['Frank', '25', 'C']
# ['Grace', '22', 'A']
# ['Hank', '24', 'B']
# ['Isla', '18', 'C']
# ['Jack', '20', 'A']

# %% [markdown]
# [Q2] Load the **students.csv** file into a pandas DataFrame. Use pandas to filter the DataFrame and create a new DataFrame containing only students who received an "A" grade. Print the new DataFrame.

# %%
import pandas as pd

df = pd.read_csv("students.csv")
a_students = df[df["Grade"] == "A"]
print(a_students)
# Out:
#        Name  Age Grade
# 0     Alice   21     A
# 3     David   23     A
# 6     Grace   22     A
# 9      Jack   20     A
# 12      Mia   24     A
# 15     Paul   19     A
# 18      Sam   21     A
# 21   Victor   24     A
# 24     Yara   18     A
# 26     Adam   19     A
# 29    Diana   24     A
# 32    Gavin   20     A
# 35    Julia   18     A
# 38    Mason   22     A
# 41    Piper   19     A
# 44    Steve   22     A
# 47     Vera   20     A
# 50    Yusuf   18     A
# 53  Brianna   24     A
# 56    Ethan   20     A

# %% [markdown]
# [Q3] Add a new column to the DataFrame called "Passed" where the value is True if the grade is "A", and False otherwise. Print the updated DataFrame.

# %%
import pandas as pd

df = pd.read_csv("students.csv")
df["Passed"] = df["Grade"] == "A"
print(df)
# Out:
#        Name  Age Grade  Passed
# 0     Alice   21     A    True
# 1       Bob   22     B   False
# 2   Charlie   20     C   False
# 3     David   23     A    True
# 4       Eve   19     B   False
# 5     Frank   25     C   False
# 6     Grace   22     A    True
# 7      Hank   24     B   False
# 8      Isla   18     C   False
# 9      Jack   20     A    True
# 10    Karen   21     B   False
# 11     Liam   22     C   False
# 12      Mia   24     A    True
# 13     Nate   23     B   False
# 14   Olivia   25     C   False
# 15     Paul   19     A    True
# 16    Quinn   18     B   False
# 17     Ruby   22     C   False
# 18      Sam   21     A    True
# 19     Tina   20     B   False
# 20      Uma   19     C   False
# 21   Victor   24     A    True
# 22    Wendy   23     B   False
# 23   Xander   22     C   False
# 24     Yara   18     A    True
# 25     Zack   20     B   False
# 26     Adam   19     A    True
# 27     Beth   22     B   False
# 28     Cody   21     C   False
# 29    Diana   24     A    True
# 30   Edward   23     B   False
# 31    Fiona   25     C   False
# 32    Gavin   20     A    True
# 33    Holly   21     B   False
# 34      Ian   19     C   False
# 35    Julia   18     A    True
# 36     Kyle   24     B   False
# 37    Laura   23     C   False
# 38    Mason   22     A    True
# 39     Nina   25     B   False
# 40    Oscar   20     C   False
# 41    Piper   19     A    True
# 42   Quincy   18     B   False
# 43     Rosa   21     C   False
# 44    Steve   22     A    True
# 45     Tori   24     B   False
# 46  Ulysses   23     C   False
# 47     Vera   20     A    True
# 48     Will   25     B   False
# 49    Xenia   19     C   False
# 50    Yusuf   18     A    True
# 51      Zoe   21     B   False
# 52    Allen   22     C   False
# 53  Brianna   24     A    True
# 54    Caleb   23     B   False
# 55    Daisy   25     C   False
# 56    Ethan   20     A    True
# 57    Faith   19     B   False
# 58   George   18     C   False

# %% [markdown]
# [Q4] Calculate the average age of the students in the DataFrame.

# %%
import pandas as pd

df = pd.read_csv("students.csv")
avg_age = df["Age"].mean()
print(avg_age)
# Out:
# 21.389830508474578

# %% [markdown]
# [Q5] Calculate the average GPAX of **ALL** students in the DataFrame, where A=4, B=3, C=2, and D=1.

# %%
import pandas as pd

df = pd.read_csv("students.csv")
grade_to_gpax = {"A": 4, "B": 3, "C": 2, "D": 1}
df["GPAX"] = df["Grade"].map(grade_to_gpax)
avg_gpax = df["GPAX"].mean()
print(avg_gpax)
# Out:
# 3.016949152542373

# %% [markdown]
# ## [2] HTML

# %% [markdown]
# ### 2.1 Different tags in HTML
#
# **Basic Structure Tags:**
#
# - `<!DOCTYPE html>`: Declares the document type and version of HTML.
# - `<html>`: Root element of the HTML document.
# - `<head>`: Contains meta-information like the title, character set, and links to external resources (CSS, scripts).
# - `<title>`: Specifies the title of the webpage, visible in the browser tab.
# - `<body>`: Contains the visible content of the page.
#
# **Text Formatting Tags:**
#
# - `<h1>` - `<h6>`: Header tags (h1 is the largest, h6 is the smallest).
# - `<p>`: Paragraph tag, used to group text into paragraphs.
# - `<blockquote>`: Defines a block of text that is a quotation from another source.
# - `<code>`: Represents inline code.
#
# **Lists and Links:**
#
# - `<ul>`: Unordered list (bulleted).
# - `<ol>`: Ordered list (numbered).
# - `<li>`: List item, used inside `<ul>` or `<ol>`.
# - `<a>`: Anchor tag, used to create hyperlinks.
# - `<img>`: Image tag, used to embed images.
#
# **Tables:**
#
# - `<table>`: Defines a table.
# - `<tr>`: Table row.
# - `<th>`: Table header, defines header cells.
# - `<td>`: Table data, defines standard cells.
#
# and more...

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ### 2.2 Writing new HTML file

# %%
html_temp = """
<!DOCTYPE html>
<html>
<head>
    <title>Sample Blog</title>
</head>
<body>
    <h2 class="article-title">Article 1: Introduction to Web Scraping</h2>
    <p class="article-content">This is an introduction to web scraping using BeautifulSoup.</p>
    <h2 class="article-title">Article 2: Advanced Web Scraping Techniques</h2>
    <p class="article-content">Learn advanced techniques for web scraping with Python.</p>
</body>
</html>
"""

with open("html_file.html", "w") as file:
    file.write(html_temp)

# %% [markdown]
# ### 2.3 Reading HTML file

# %%
with open("html_file.html") as html_file:
    html_content = html_file.read()

# Parse the HTML content
soup = BeautifulSoup(html_content, "html.parser")

print(soup.title.text)
print(soup.h2)
print(soup.table.text)
# Out:
# Sample Blog
# <h2 class="article-title">Article 1: Introduction to Web Scraping</h2>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 9
#       7 print(soup.title.text)
#       8 print(soup.h2)
# ----> 9 print(soup.table.text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# [Q6] Explain why the code above gives an error? Fix the code so that it runs without error.
#
# Ans: The HTML we created has no `<table>` element, so `soup.table` is `None` and calling `.text` on it causes an `AttributeError`.

# %%
from bs4 import BeautifulSoup

with open("html_file.html") as html_file:
    html_content = html_file.read()

soup = BeautifulSoup(html_content, "html.parser")

print(soup.title.text)
print(soup.h2)
# There is no table tag in this HTML, so we must not access soup.table.text
# Out:
# Sample Blog
# <h2 class="article-title">Article 1: Introduction to Web Scraping</h2>

# %% [markdown]
# [Q7] You are provided an HTML file named **students.html**. Write a Python script that extracts all the data from the table (headers and rows) and prints them row by row.

# %%
from bs4 import BeautifulSoup

with open("students.html") as file:
    soup = BeautifulSoup(file, "html.parser")

table = soup.find("table")
rows = table.find_all("tr")

for row in rows:
    cells = [cell.get_text(strip=True) for cell in row.find_all(["th", "td"])]
    print(cells)
# Out:
# ['Name', 'Age', 'Grade']
# ['Alice', '21', 'A']
# ['Bob', '22', 'B']
# ['Charlie', '20', 'C']
# ['David', '23', 'A']
# ['Eve', '19', 'B']
# ['Frank', '25', 'C']
# ['Grace', '22', 'A']
# ['Hank', '24', 'B']
# ['Isla', '18', 'C']
# ['Jack', '20', 'A']
# ['Karen', '21', 'B']
# ['Liam', '22', 'C']
# ['Mia', '24', 'A']
# ['Nate', '23', 'B']
# ['Olivia', '25', 'C']
# ['Paul', '19', 'A']
# ['Quinn', '18', 'B']
# ['Ruby', '22', 'C']
# ['Sam', '21', 'A']
# ['Tina', '20', 'B']
# ['Uma', '19', 'C']
# ['Victor', '24', 'A']
# ['Wendy', '23', 'B']
# ['Xander', '22', 'C']
# ['Yara', '18', 'A']
# ['Zack', '20', 'B']

# %% [markdown]
# [Q8] Modify the script to extract and print only the names of students who received a grade of "A".

# %%
from bs4 import BeautifulSoup

with open("students.html") as file:
    soup = BeautifulSoup(file, "html.parser")

table = soup.find("table")
tbody = table.find("tbody")

for row in tbody.find_all("tr"):
    cols = row.find_all("td")
    name = cols[0].get_text(strip=True)
    grade = cols[2].get_text(strip=True)
    if grade == "A":
        print(name)
# Out:
# Alice
# David
# Grace
# Jack
# Mia
# Paul
# Sam
# Victor
# Yara

# %% [markdown]
# ## [3] XML

# %%
import xml.etree.ElementTree as ET

# %% [markdown]
# ### 3.1 Writing new xml file

# %%
root = ET.Element("data")
student = ET.SubElement(root, "student", name="Alice")

email = ET.SubElement(student, "email")
email.text = "alice@mail.com"

age = ET.SubElement(student, "age")
age.text = "21"

gender = ET.SubElement(student, "gender")
gender.text = "F"

tree = ET.ElementTree(root)
tree.write("xml_file.xml")

# %% [markdown]
# ### 3.2 Modifying existing xml file

# %%
tree = ET.parse("xml_file.xml")
root = tree.getroot()

for student in root:
    for element in student:
        if element.tag == "age":
            element.text = "22"

tree.write("xml_file.xml")

# %% [markdown]
# ### 3.3 Reading XML file

# %%
tree = ET.parse("xml_file.xml")
root = tree.getroot()

for student in root:
    print(f"name: {student.attrib['name']}")
    for element in student:
        print(f"{element.tag}: {element.text}")

# Print the entire XML content
xml_content = ET.tostring(root, encoding="utf-8").decode("utf-8")
print(xml_content)
# Out:
# name: Alice
# email: alice@mail.com
# age: 22
# gender: F
# <data><student name="Alice"><email>alice@mail.com</email><age>22</age><gender>F</gender></student></data>

# %% [markdown]
# ### 3.4 Convert XML to List of Dictionary

# %%
data_list = []
for line in root:
    name = line.attrib.get("name")
    email = line.find("email").text
    age = line.find("age").text
    gender = line.find("gender").text

    data_list.append({"Name": name, "Email": email, "Age": age, "Gender": gender})

print(data_list)
# Out:
# [{'Name': 'Alice', 'Email': 'alice@mail.com', 'Age': '22', 'Gender': 'F'}]

# %% [markdown]
# [Q9] Add your own data including Name, Email, Age and Gender to the XML file and put it in the existing data_list.
#
# _Note: You should show the data_list and XML file by reading the file._

# %%
import xml.etree.ElementTree as ET

# Read existing XML
tree = ET.parse("xml_file.xml")
root = tree.getroot()

# Add new student
new_student = ET.SubElement(root, "student", name="John")
email = ET.SubElement(new_student, "email")
email.text = "john@mail.com"
age = ET.SubElement(new_student, "age")
age.text = "20"
gender = ET.SubElement(new_student, "gender")
gender.text = "M"

# Save back to file
tree.write("xml_file.xml")

# Read again and rebuild data_list
tree = ET.parse("xml_file.xml")
root = tree.getroot()

data_list = []
for student in root:
    name = student.attrib.get("name")
    email = student.find("email").text
    age = student.find("age").text
    gender = student.find("gender").text
    data_list.append({"Name": name, "Email": email, "Age": age, "Gender": gender})

print(data_list)

# Show XML content
xml_content = ET.tostring(root, encoding="utf-8").decode("utf-8")
print(xml_content)
# Out:
# [{'Name': 'Alice', 'Email': 'alice@mail.com', 'Age': '22', 'Gender': 'F'}, {'Name': 'John', 'Email': 'john@mail.com', 'Age': '20', 'Gender': 'M'}, {'Name': 'John', 'Email': 'john@mail.com', 'Age': '20', 'Gender': 'M'}]
# <data><student name="Alice"><email>alice@mail.com</email><age>22</age><gender>F</gender></student><student name="John"><email>john@mail.com</email><age>20</age><gender>M</gender></student><student name="John"><email>john@mail.com</email><age>20</age><gender>M</gender></student></data>

# %% [markdown]
# ## [4] JSON

# %%
import json

# %% [markdown]
# ### 4.1 Writing new json file

# %%
# Data to be written to the JSON file
data_to_write = {
    "people": [
        {"name": "Alice", "age": 30, "city": "New York"},
        {"name": "Bob", "age": 25, "city": "San Francisco"},
        {"name": "Charlie", "age": 35, "city": "Los Angeles"},
    ]
}

# Open the file in write mode and write the data
with open("json_file", "w") as json_file:
    json.dump(data_to_write, json_file, indent=2)

# %% [markdown]
# ### 4.2 Reading json file

# %%
with open("json_file", "r") as file:
    # Load JSON data
    data = json.load(file)

print(data)

people = data["people"]

# Print information about each person
for person in people:
    print(f"Name: {person['name']}, Age: {person['age']}, City: {person['city']}")
# Out:
# {'people': [{'name': 'Alice', 'age': 30, 'city': 'New York'}, {'name': 'Bob', 'age': 25, 'city': 'San Francisco'}, {'name': 'Charlie', 'age': 35, 'city': 'Los Angeles'}]}
# Name: Alice, Age: 30, City: New York
# Name: Bob, Age: 25, City: San Francisco
# Name: Charlie, Age: 35, City: Los Angeles

# %% [markdown]
# [Q10] write a code to modify the existing json file so each person have a "job" data and print the result
#
# Ans:

# %%
import json

with open("json_file", "r") as json_file:
    data = json.load(json_file)

for person in data["people"]:
    person["job"] = "Engineer"  # or any job you choose

with open("json_file", "w") as json_file:
    json.dump(data, json_file, indent=2)

print(data)
for person in data["people"]:
    print(
        f"Name: {person['name']}, Age: {person['age']}, "
        f"City: {person['city']}, Job: {person['job']}"
    )
# Out:
# {'people': [{'name': 'Alice', 'age': 30, 'city': 'New York', 'job': 'Engineer'}, {'name': 'Bob', 'age': 25, 'city': 'San Francisco', 'job': 'Engineer'}, {'name': 'Charlie', 'age': 35, 'city': 'Los Angeles', 'job': 'Engineer'}]}
# Name: Alice, Age: 30, City: New York, Job: Engineer
# Name: Bob, Age: 25, City: San Francisco, Job: Engineer
# Name: Charlie, Age: 35, City: Los Angeles, Job: Engineer
